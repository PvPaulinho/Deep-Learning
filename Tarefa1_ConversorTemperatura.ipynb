# %% [markdown]
# # Tarefa 1 - Conversor de unidades de temperatura
#
# Você encontrou um termomêtro com a seguintes escalas (sem a indicação de unidade):
#
# |x|y|
# |--|--|
# |0 | 32|
# |5| 41|
# |10| 50|
# |20|68|
# |30|86|
# |40|104|
#
# - Treine uma rede neural para modelar a relação x-y (um neurônio, uma camada)
# - Qual é a temperatura em y quando x = 38?
# - Dica: para facilitar a convergência, escalone as entradas (por exemplo dividindo por 10).

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
x = np.array([0.0,  0.5, 1.0, 2.0, 3.0, 4.0], dtype=float)
y = np.array([3.2, 4.1, 5.0, 6.8, 8.6, 10.4], dtype=float)
model.fit(x, y, epochs=500)
print(model.predict([38]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 236ms/step - loss: 12.7653
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 10.6215
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.9299
# Epoch 4/500
# 1/1 [==============================] - 0s 8ms/step - loss: 7.5934
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.5360
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6977
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0317
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.5010
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.0766
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.7359
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.4610
# Epoch 12/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2378
# ...
